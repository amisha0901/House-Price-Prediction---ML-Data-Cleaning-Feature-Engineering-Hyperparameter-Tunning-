# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('../../datasets/house_train.csv')

# %%
plt.hist(df_train['SalePrice'])
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <BarContainer object of 10 artists>)

# %%
df_train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df_train['SalePrice'].median()
# Out:
# 163000.0

# %%
plt.boxplot(df_train['SalePrice'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f4c0712260>,
#   <matplotlib.lines.Line2D at 0x1f4c0712500>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f4c07127a0>,
#   <matplotlib.lines.Line2D at 0x1f4c0712a40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f4c07120e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f4c0712ce0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f4c0712f80>],
#  'means': []}

# %%
q1 = df_train['SalePrice'].describe()['25%']
q3 = df_train['SalePrice'].describe()['75%']
IQR = q3-q1
LT = q1-1.5*(IQR)
HT = q3+1.5*(IQR)
LT, HT
# Out:
# (3937.5, 340037.5)

# %% [markdown]
# # Z_score

# %%
X = df_train['SalePrice']
Z = (X-X.mean())/X.std()

# %%
sum((Z>-1) & (Z<=1))
# Out:
# 1145

# %%
1145/1460
# Out:
# 0.7842465753424658

# %%
sum((Z>-2) & (Z<=2)) / 1460
# Out:
# 0.9568493150684931

# %%
sum((Z>-3) & (Z<=3)) / 1460
# Out:
# 0.9849315068493151

# %%
0.9568*1460
# Out:
# 1396.9279999999999
